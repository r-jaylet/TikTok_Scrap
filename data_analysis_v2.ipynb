# %%
import pandas as pd
import numpy as np
import ast
from collections import Counter
import matplotlib.pyplot as plt
import seaborn

# %%
seaborn.set()

# %%
data = pd.read_csv('1000_musicians.csv')
data.head(3)
# Out:
#             user_name        nickname  \
# 0       benedictquinn       Ben Quinn
# 1  jasmineoakleymusic  Jasmine Oakley
# 2       pastelmusique          Ｐａｓｔｅｌ
#
#                                            signature  verified  \
# 0  oh hey!\r\nguitarist and producer \r\ngo follo...     False
# 1                                   Singer/Artist  ✨     False
# 2                        FOLLOW ME ON IG ✨\r\nＰａｓｔｅｌ     False
#
#    follower_count  following_count  likes_count  video_count last_active  \
# 0             804              135         4962           69  2021-11-03
# 1            5536               58        65200           54  2022-01-02
# 2            1058               81         4627           73  2022-01-02
#
#                                             mentions duos  \
# 0                             ['jasmineoakleymusic']   []
# 1  ['pastelmusique', 'benedictquinn', 'thatdapper...   []
# 2  ['bomelmusic', 'katpenkin', 'jasmineoakleymusi...   []
#
#                                              collabs  \
# 0                             ['jasmineoakleymusic']
# 1  ['pastelmusique', 'benedictquinn', 'thatdapper...
# 2  ['bomelmusic', 'katpenkin', 'jasmineoakleymusi...
#
#                                          collabs_url  \
# 0  {'jasmineoakleymusic': 'https://v16-webapp.tik...
# 1  {'pastelmusique': 'https://v16-webapp.tiktok.c...
# 2  {'bomelmusic': 'https://v16-webapp.tiktok.com/...
#
#                                             hashtags  \
# 0  ['asktiktok', 'music', 'instrumental', 'chill'...
# 1  ['beats', 'rnb', 'singer', 'vocalist', 'riffs'...
# 2  ['tiktokmusique', 'groovy', 'funktiktok', 'mus...
#
#                             instruments  \
# 0          ['guitar', 'bass', 'chords']
# 1  ['guitar', 'bass', 'piano', 'drums']
# 2                                    []
#
#                                               styles
# 0  ['rnb', 'hiphop', 'indie', 'groove', 'neosoul'...
# 1        ['jazz', 'rap', 'rnb', 'neosoul', 'gospel']
# 2                                                 []

# %%
data.groupby(data.verified).count().user_name.plot.pie(title = 'Repartition verified users', figsize=(11, 6))
# Out:
# <AxesSubplot:title={'center':'Repartition verified users'}, ylabel='user_name'>

# %%
data.follower_count.plot.hist(title = 'Distrubituion du nombre de followers par utilisateurs', figsize=(11, 6), bins=20)
# Out:
# <AxesSubplot:title={'center':'Distrubituion du nombre de followers par utilisateurs'}, ylabel='Frequency'>

# %%
data[data['following_count'] < 3000].following_count.plot.hist(title = 'Distrubituion du nombre de followings par utilisateurs', figsize=(11, 6), bins=20)
# Out:
# <AxesSubplot:title={'center':'Distrubituion du nombre de followings par utilisateurs'}, ylabel='Frequency'>

# %%
data[data['likes_count'] < 50000].likes_count.plot.hist(title = 'Distrubituion du nombre de likes par utilisateurs', figsize=(11, 6), bins=20)
# Out:
# <AxesSubplot:title={'center':'Distrubituion du nombre de likes par utilisateurs'}, ylabel='Frequency'>

# %%
fig, ax = plt.subplots(figsize=(11,6))

H = []
for i in range(len(data)):
    H.append(len(ast.literal_eval(data.collabs[i])))
counter = Counter(H)
res = Counter({k: c for k, c in counter.items()})
plt.bar(res.keys(), res.values())
plt.title('Nombre de collabs')
# Out:
# Text(0.5, 1.0, 'Nombre de collabs')

# %%
fig, ax = plt.subplots(figsize=(16,6))

H = []
for i in range(len(data)):
    H_line = ast.literal_eval(data.hashtags[i])
    for w in H_line:
         H.append(w)

counter = Counter(H)
res = Counter({k: c for k, c in counter.items() if c > 25})
plt.bar(res.keys(), res.values())
plt.title('Nombre dutilisation des hashtags les plus fréquents')
# Out:
# Text(0.5, 1.0, 'Nombre dutilisation des hashtags les plus fréquents')

# %%
counter
# Out:
# Counter({'asktiktok': 2,
#          'music': 73,
#          'instrumental': 5,
#          'chill': 3,
#          'lofi': 8,
#          'duetwithme': 22,
#          'lofihiphop': 6,
#          'guitar': 65,
#          'beat': 7,
#          'chillmusic': 1,
#          'naturevibes': 1,
#          'lofichill': 1,
#          'musicforyou': 1,
#          'fypシ': 39,
#          'fyp': 108,
#          'indie': 11,
#          'indiemusic': 10,
#          'acoustic': 24,
#          'singersongwriter': 13,
#          'chillvibes': 1,
#          'vibes': 11,
#          'bass': 28,
#          'vibe': 6,
#          'nature': 3,
#          'rnb': 12,
#          'chords': 10,
#          'neosoul': 7,
#          'loop': 8,
#          'guitartutorial': 3,
#          'pickupmusic': 1,
#          'jazztok': 9,
#          'groove': 10,
#          'lofibeat': 5,
#          'hiphop': 19,
#          'foryoupage': 25,
#          'beats': 14,
#          'singer': 33,
#          'vocalist': 4,
#          'riffs': 4,
#          'fy': 9,
#          'guitarist': 12,
#          'drums': 36,
#          'freeme': 1,
#          'bossa': 1,
#          'clones': 1,
#          'soul': 9,
#          'gospel': 5,
#          'piano': 28,
#          'riff': 13,
#          'soulmusic': 3,
#          'producer': 20,
#          'outdoors': 1,
#          'jazz': 19,
#          'songwriter': 19,
#          'vocals': 19,
#          'cover': 30,
#          'shilohdynasty': 1,
#          'voiceeffects': 16,
#          'alexisley': 1,
#          'pjmorton': 1,
#          'vcalist': 1,
#          'harmonies': 6,
#          'freestyle': 5,
#          'rap': 7,
#          'keys': 3,
#          'production': 3,
#          'jheneaikovibes': 1,
#          'femaleproducer': 3,
#          'tiktokmusique': 1,
#          'groovy': 3,
#          'funktiktok': 1,
#          'musicproducer': 11,
#          'idsong': 1,
#          'gfunk': 1,
#          'funkopop': 1,
#          'pourtoi': 1,
#          'beatmaker': 8,
#          'tiktokrewind2021': 1,
#          'rewindchallenge': 1,
#          '2021': 17,
#          'foryou2021': 1,
#          'foryou2022': 1,
#          'tiktokmusic': 4,
#          'christmassong': 3,
#          'rnbvibes': 1,
#          'rnbtok': 1,
#          'france🇫🇷': 1,
#          'welcometofrance': 1,
#          'frenchmorning': 1,
#          'livemusic': 13,
#          'bossanova': 2,
#          'rnbsinger': 1,
#          'neosoulmusic': 1,
#          'femalesinger': 1,
#          'indiepopmusic': 1,
#          'studiosessions': 1,
#          'lofivibes': 1,
#          'omgvoices': 1,
#          'neosoulguitar': 3,
#          'neosoulvibes': 1,
#          'rnbmusic': 1,
#          'originalmusic': 12,
#          'coversong': 10,
#          'britneychallenge': 1,
#          'britneyspears': 3,
#          'jazzpiano': 1,
#          'pianomusic': 1,
#          'lofijazz': 1,
#          'femalevocalist': 1,
#          'fypp': 1,
#          'housemusic': 2,
#          'originalsong': 8,
#          'houseoftiktok': 1,
#          'techno': 1,
#          'fypage': 4,
#          'partytime': 1,
#          'aftershow': 1,
#          'wildparty': 1,
#          'partygirl': 1,
#          'christmas': 39,
#          'ewf': 1,
#          'september': 1,
#          'feelgood': 1,
#          'pop': 7,
#          'effect': 1,
#          'synths': 1,
#          'head': 1,
#          'duet': 128,
#          'musician': 29,
#          'unresolved': 1,
#          'flutetok': 3,
#          'videogamemusic': 3,
#          'videogamejazz': 1,
#          'nintendo': 5,
#          'ds': 1,
#          'ost': 1,
#          'jazzfusion': 3,
#          'stitch': 46,
#          'thelicc': 1,
#          'licctok': 1,
#          'flugelhorn': 1,
#          'dog': 6,
#          'mariokart': 1,
#          'remix': 6,
#          'foryou': 39,
#          'mybrawlsuper': 12,
#          'brighton': 1,
#          'viral': 19,
#          'bts': 2,
#          'musicvideo': 8,
#          'bigasyoox': 2,
#          'simsselves': 6,
#          'spotifywrapped': 8,
#          'vanscheckerboardday': 3,
#          'justdanceitout': 2,
#          'hercules': 2,
#          'drinking': 1,
#          'tkmaxxtalentshow': 3,
#          'katpenkin': 1,
#          'abettertime': 1,
#          'newmusic': 27,
#          'customersmostloved': 8,
#          'asoschaostocalm': 1,
#          'verypjportraits': 1,
#          'honor50duet': 2,
#          'carcrash': 1,
#          'drake': 3,
#          'takingcareofbiz': 2,
#          'singers': 15,
#          'cute': 3,
#          'steviewonder': 4,
#          'jacobcollier': 3,
#          'singingchallenge': 3,
#          'twobestfriendsinaroom': 1,
#          'bossupyourgame': 1,
#          'bestie': 3,
#          'uni': 1,
#          'uni2021': 1,
#          'jazminesullivan': 4,
#          'insecureriffchallenge': 1,
#          'jazminesullivanriffchallenge': 1,
#          'singersoftiktok': 13,
#          'insecure': 2,
#          'butterfly': 1,
#          'artist': 6,
#          'dogsoftiktok': 1,
#          'flutebae': 1,
#          'blackmusicians': 1,
#          'musiciansoftiktok': 41,
#          'blackcreatorsoftiktok': 1,
#          'musiciantok': 2,
#          'smallblackbusiness': 1,
#          'flutist': 1,
#          'blackcreatives': 1,
#          '1stviral': 1,
#          'dancetok': 1,
#          'flutistsoftiktok': 1,
#          '4thofjuly': 1,
#          'july4th': 1,
#          'flute': 2,
#          'flutistoftiktok': 1,
#          'musiccover': 3,
#          'avengers': 2,
#          'marvel': 4,
#          'letsrock': 1,
#          'smash': 1,
#          'satisfying': 1,
#          'wewillrockyou': 1,
#          'drum': 6,
#          'streamer': 1,
#          'drummer': 14,
#          'twitch': 2,
#          'musicstreamer': 1,
#          'ow': 1,
#          'smooth': 1,
#          'thanksandgiving': 15,
#          'makeabunchhappen': 14,
#          'jams': 2,
#          'cymbals': 2,
#          'cymbalmodification': 1,
#          'sabiancymbals': 1,
#          'funk': 9,
#          'donnalee': 1,
#          'swing': 2,
#          'jazztrio': 1,
#          'drumsolo': 3,
#          '12inchbassdrum': 1,
#          'vgm': 1,
#          'jamsession': 3,
#          'donkeykong': 1,
#          'retrovideogames': 1,
#          'sharethemagic': 6,
#          'dothejuju': 8,
#          'drummix': 1,
#          'mixing': 2,
#          'producing': 1,
#          'newmics': 1,
#          'earthworks': 1,
#          'undertale': 2,
#          'retrogaming': 3,
#          'dadjokes': 1,
#          'wurlitzer200a': 1,
#          'itsyouilike': 1,
#          'yourhonorimsorry': 1,
#          'kiefer': 1,
#          'whenthereslovearound': 1,
#          'tour': 5,
#          'synth': 6,
#          'solo': 6,
#          'saucyvadeduet': 1,
#          'vadeduets': 1,
#          'vadesings': 2,
#          'vade': 1,
#          'boyziimen': 1,
#          'acapella': 6,
#          'cyndilauper': 1,
#          'timeaftertime': 1,
#          'vadecovers': 1,
#          'chakakhan': 1,
#          'anitabaker': 1,
#          'harmony': 7,
#          'jazzduet': 1,
#          'swv': 1,
#          'weak': 1,
#          'h': 1,
#          'tiktoksingers': 1,
#          'vadé': 1,
#          'vadéduets': 1,
#          'tokyoolympics': 1,
#          'beyonce': 3,
#          'loveontop': 1,
#          'norahjones': 1,
#          'dontknowwhy': 1,
#          'foryourpage': 7,
#          'usher': 1,
#          'myboochallenge': 1,
#          'tiktoksinger': 1,
#          'lit': 1,
#          'blacktok': 1,
#          'myboo': 1,
#          'usherchallenge': 1,
#          'popcornduet': 2,
#          'explore': 1,
#          'vocalgroup': 1,
#          'brothers': 1,
#          'newyear': 18,
#          'goals': 3,
#          'newyearsresolution': 3,
#          'singinggoals': 1,
#          'voiceteacher': 1,
#          'vocalcoach': 2,
#          'voicelessons': 1,
#          'voicelesson': 1,
#          'howtosing': 1,
#          'learntosing': 1,
#          'theatre': 5,
#          'musicaltheatre': 12,
#          'broadway': 8,
#          'belt': 2,
#          'mix': 1,
#          'mixvoice': 2,
#          'mixedvoice': 1,
#          'riffchallenge': 5,
#          'breakingdowntheriffs': 1,
#          'valerie': 3,
#          'riffsandruns': 4,
#          'learntoriff': 1,
#          'sneakpeek': 1,
#          'adele': 7,
#          'easyonme': 4,
#          'theatrekid': 6,
#          'singinglessons': 1,
#          'answer': 13,
#          'askontiktok': 3,
#          'tiktokromance': 1,
#          'alliwantforchristmas': 3,
#          'mariahcarey': 7,
#          'christmasmusic': 7,
#          'holidaymusic': 2,
#          'happyholidays': 6,
#          'holidays': 5,
#          'top5': 2,
#          'geicogivehappy': 10,
#          'choralmusic': 1,
#          'voiceteacherreacts': 1,
#          'vocalcoachreacts': 1,
#          'choir': 1,
#          'choirkid': 1,
#          'acappella': 4,
#          'whenriftansays': 7,
#          'simplythebest': 1,
#          'noahreid': 1,
#          'schittscreek': 2,
#          'tinaturner': 1,
#          'dancingqueen': 1,
#          'dancingqueenchallenge👑': 1,
#          'onebreathchallenge': 1,
#          'alwayslearning': 1,
#          'alwaysimproving': 1,
#          'thankful': 4,
#          'altochallenge': 1,
#          'lownotes': 1,
#          'duetme': 10,
#          'singingtips': 1,
#          'comedy': 15,
#          'funnyvideos': 2,
#          'musiclessons': 1,
#          'stitchthis': 4,
#          'specialskills': 1,
#          'hiddentalents': 1,
#          'resume': 1,
#          'whistle': 2,
#          'whistler': 1,
#          'sweetgeorgiabrown': 1,
#          'harlemglobetrotters': 1,
#          'disney': 8,
#          'givewithallyourheart': 3,
#          'onceuponeatime': 1,
#          'brooklyn': 2,
#          'mixbelt': 1,
#          'vocalhealth': 1,
#          'coldandfluseason': 1,
#          'notadoctor': 1,
#          'ijustplayoneontv': 1,
#          'fantasyfootball': 1,
#          'jokes': 3,
#          'christiantiktok': 1,
#          'myfathershouse': 1,
#          'biblestories': 1,
#          'god': 1,
#          'jesus': 2,
#          'bible': 1,
#          'church': 2,
#          'truth': 2,
#          'taekwondo': 1,
#          'slowmo': 1,
#          'cymbal': 1,
#          'craftsman': 1,
#          'fastafboiiiii': 1,
#          'blackfriday': 1,
#          'cheapthrills': 1,
#          'gameshow': 1,
#          'patreon': 3,
#          'weird': 2,
#          'musiccitydrumshow': 1,
#          'batch': 1,
#          'producersoftiktok': 6,
#          'ambient': 4,
#          'accordion': 1,
#          'holiday': 9,
#          'singing': 37,
#          'advice': 2,
#          'tips': 2,
#          'songwriting': 10,
#          'howto': 4,
#          'tuba': 1,
#          '2021recap': 4,
#          'op1': 1,
#          'teenageengineering': 2,
#          'denver': 1,
#          'colorado': 3,
#          'sequencer': 1,
#          'synthesizer': 1,
#          'collab': 9,
#          'melody': 2,
#          'donkeykongcountry': 1,
#          'aquaticambience': 1,
#          'snes': 2,
#          'davidwise': 1,
#          'videogames': 2,
#          'co': 1,
#          'duetthis': 22,
#          'animemusic': 1,
#          'love': 11,
#          'fallinlove': 1,
#          'jdilla': 2,
#          'slumvillage': 1,
#          'jaydee': 1,
#          'dontsellyourself': 1,
#          'pokemon': 2,
#          'professoroak': 1,
#          'gameboy': 1,
#          'tobyfox': 1,
#          'undertalemusic': 1,
#          'pianoplaying': 1,
#          'bells': 1,
#          'xylophone': 1,
#          'mychemicalromance': 1,
#          'theblackparade': 1,
#          'welcometotheblackparade': 1,
#          'emo': 17,
#          'emomusic': 3,
#          'mcr': 1,
#          'guitars': 2,
#          'guitarra': 4,
#          'recording': 9,
#          'guitarlesson': 4,
#          'learnguitar': 2,
#          'guitarteacher': 1,
#          'frankocean': 1,
#          'theisleybrothers': 1,
#          'endless': 1,
#          'oddfuture': 1,
#          'opinion': 1,
#          'nes': 1,
#          '8bit': 1,
#          'jazzy': 1,
#          'chilledmusic': 1,
#          'saxophone': 1,
#          'jam': 5,
#          'wurli': 1,
#          'disco': 3,
#          'dance': 7,
#          'ableton': 3,
#          '4onthefloor': 1,
#          'dancebeat': 1,
#          'hiphopbeat': 3,
#          'rhodes': 1,
#          'saucyvocals': 1,
#          'whistletone': 2,
#          'classic': 2,
#          'kekewyatt': 1,
#          'run': 1,
#          'leandriajohnson': 1,
#          'parisbennett': 1,
#          'throwback': 6,
#          'terrellshow': 1,
#          'callieday': 2,
#          'greenscreen': 18,
#          'meifiwere': 1,
#          'whichvoicefitsmebest': 1,
#          'natasharomanoff': 1,
#          'wandavision': 1,
#          'wandamaximoff': 1,
#          'yelenabelova': 1,
#          'peggycarter': 1,
#          'blackwidow': 1,
#          'thegrinch': 3,
#          'thegrinchwhostolechristmas': 1,
#          'blackcat': 1,
#          'blackcats': 1,
#          'cats': 5,
#          'christmasvillage': 1,
#          'christmasdecor': 2,
#          'chesnutsroasting': 1,
#          'thechristmassong': 1,
#          'homealone': 1,
#          'thisisme': 1,
#          'howthegrinchstolechristmas': 1,
#          'cindylouwho': 1,
#          'diva': 1,
#          'beingalive': 1,
#          'stephensondheim': 1,
#          'mgm': 1,
#          'motionpictures': 1,
#          'movies': 4,
#          'lion': 1,
#          'preview': 1,
#          'frostythesnowman': 2,
#          'pentatonix': 1,
#          'aidraws': 1,
#          'spongebob': 4,
#          'patrickstar': 1,
#          'wombo': 1,
#          'wambo': 1,
#          'company': 2,
#          '2022': 21,
#          'song': 12,
#          'christoferscott': 1,
#          'gay': 4,
#          'lgbt': 4,
#          'wydnow': 5,
#          'sadiejean': 2,
#          'original': 3,
#          'showme': 1,
#          'amywinhouse': 2,
#          'duets': 10,
#          'inprogress': 1,
#          'billwithers': 1,
#          'lyrics': 2,
#          'originalchristmassong': 2,
#          'songwritersoftiktok': 8,
#          'unsignedartist': 4,
#          'pleaseduetthis': 1,
#          'adelecover': 1,
#          'malefantasybillie': 1,
#          'billiecover': 1,
#          'harmoniesduet': 1,
#          'vocallayering': 1,
#          'malefantasybillieeilish': 1,
#          'billieeilishcover': 1,
#          'thefray': 2,
#          'thefraycover': 1,
#          'hammondorgan': 1,
#          'winterbreakisover': 1,
#          'baritoneukulele': 1,
#          'studiocat': 1,
#          'acousticcover': 4,
#          'sohotyourehurtingmyfeelings': 1,
#          'songtitlechallenge': 2,
#          'auldlangsyne': 4,
#          'cupofkindness': 1,
#          'cheerstoyou': 1,
#          'newyearnewyou': 1,
#          'treatyourself': 2,
#          'letgo': 2,
#          'therapy': 2,
#          'sleepcycles': 1,
#          'bestpractice': 1,
#          'practicetips': 1,
#          'segmentedsleep': 1,
#          'segmented': 1,
#          'leomindset': 1,
#          'keeppracticingmyman': 1,
#          'studiotip': 1,
#          'producertok': 6,
#          'selfcare': 1,
#          'cleanhair': 1,
#          'tubaduet': 1,
#          'tubatok': 1,
#          'forchristmas': 1,
#          'morelentilsplease': 1,
#          'getback': 6,
#          'whichbeatleami': 1,
#          'harrypotterhouses': 1,
#          'snacksfortherevolution': 1,
#          'veganbro': 1,
#          'vegansnacks': 1,
#          'traderjoescookbook': 1,
#          'letsgo': 2,
#          'guitartok': 47,
#          'fastguitar': 1,
#          'tbt': 3,
#          'dadlife': 1,
#          'kidquestions': 1,
#          'athome': 1,
#          'frozen': 3,
#          'electricguitar': 1,
#          'hawaii': 3,
#          'dreya': 1,
#          'baddie': 1,
#          'funny': 13,
#          'millenialsoftiktok': 1,
#          'sza': 3,
#          'ihateu': 3,
#          'iameverything': 1,
#          'skittles': 1,
#          'socks': 1,
#          'babybash': 1,
#          'tpain': 1,
#          'parents': 1,
#          'whydoe': 1,
#          'destinyschild': 2,
#          'singerstoknow': 2,
#          'trumpettok': 1,
#          'trumpet': 3,
#          'bloopers': 2,
#          'lacucaracha': 1,
#          'musicmemes': 1,
#          'thisisterrible': 1,
#          'musictok': 12,
#          'christmastothemaxx': 1,
#          'educationalvideo': 1,
#          'themetok': 1,
#          'trombone': 2,
#          'yalikejazz': 1,
#          'musiciansontiktok': 3,
#          'looptok': 1,
#          'yebba': 2,
#          'yebbasmith': 1,
#          'viraltalent': 1,
#          'duo': 2,
#          'bryanwilson': 1,
#          'sang': 2,
#          'groupchat': 1,
#          'minieriperton': 1,
#          'joshualedet': 1,
#          'terrellgrice': 2,
#          'melisma': 1,
#          'talent': 1,
#          'runoftheday': 1,
#          'tamelamann': 1,
#          'thebluewall': 1,
#          'theterrellshow': 1,
#          'chanel': 1,
#          'singyourheartout': 1,
#          'whereyouat': 1,
#          'youtuber': 1,
#          'kellyprice': 1,
#          'theclarksisters': 1,
#          'nameitclaimit': 1,
#          'jackyclarkchisholm': 1,
#          'tenor': 2,
#          'mattiemossclark': 1,
#          'notkarltonbanks': 1,
#          'fordmaverick': 1,
#          'bombpopawards': 1,
#          'blackchurchesbelike': 1,
#          'fyourpage': 1,
#          'virall': 1,
#          'calliedaydancechallenge': 1,
#          'calliedaychallenge': 1,
#          'range': 1,
#          'vocalrang': 1,
#          'rhianna': 2,
#          'summerwalker': 1,
#          'billieeilish': 3,
#          'icecream': 2,
#          'bluewall': 1,
#          'newepisode': 1,
#          'makemomepic': 1,
#          'soultaker': 1,
#          'shit': 1,
#          'boburnham': 3,
#          'fritolayrickroll': 17,
#          'xyzbca': 5,
#          'merrychristmas': 9,
#          'cashapp13plus': 6,
#          'leftist': 2,
#          'politics': 2,
#          'holidaysourway': 1,
#          'aeholidayforever': 7,
#          'sound': 2,
#          'singlingles': 1,
#          'pawlidaypics': 1,
#          'cockytatertot?': 1,
#          'adamsandler': 1,
#          'sadamandler': 1,
#          'iknowwhatyoudid': 1,
#          'makeitcinematic': 3,
#          'foryoupizza': 3,
#          'ourtable': 1,
#          'aviddustcollecter': 1,
#          'misty': 1,
#          'ellafitzgerald': 1,
#          'instrument': 2,
#          'chromatic': 1,
#          'coldplay': 1,
#          'covidcover': 1,
#          'thescientist': 1,
#          'silentnight': 4,
#          'marydidyouknow': 1,
#          'yebbatok': 1,
#          'paranoiapurple': 1,
#          'classical': 3,
#          'sondheimforever': 1,
#          'clairdelune': 1,
#          'frosty': 1,
#          'hadestown': 2,
#          'musical': 5,
#          'orpheus': 1,
#          'maria': 1,
#          'sondheim': 3,
#          'intothewoods': 3,
#          'motivation': 1,
#          'diiv': 1,
#          'tabs': 1,
#          'artistsoftiktok': 8,
#          'shoegaze': 2,
#          'postpunk': 2,
#          'learnsomethingnew': 1,
#          'learnontiktok': 2,
#          'photographytricks': 1,
#          'photography': 3,
#          'winterfit': 1,
#          'dreampop': 2,
#          'ed': 1,
#          'hello2022': 3,
#          'fingerscrossed': 1,
#          'demilovato': 1,
#          'altogetherdifferent': 2,
#          'christmascover': 3,
#          'christmascarol': 2,
#          'michealbublé': 1,
#          'hotchocolate': 1,
#          'festivefashion': 2,
#          'acousticcovers': 12,
#          'awaydays': 1,
#          'photodump': 1,
#          'johnlegend': 2,
#          'amywinehouse': 2,
#          'acousticguitar': 9,
#          'fingerstyleguitar': 1,
#          'guitartips': 2,
#          'guitarchords': 1,
#          'neoaoul': 1,
#          'jazzguitar': 1,
#          'guitarlicks': 2,
#          'rnbguitar': 2,
#          'fingerpicking': 1,
#          'sologuitar': 1,
#          'guitarloop': 1,
#          'playguitar': 1,
#          'guitaristsoftiktok': 7,
#          'fingerstyle': 1,
#          'playinggames': 1,
#          'sunmerwalker': 1,
#          'danelectro': 1,
#          'guitarlick': 2,
#          'guitarriff': 2,
#          'isntshelovely': 1,
#          'guitarplayer': 5,
#          'guitarsolo': 10,
#          'tadow': 1,
#          'masego': 1,
#          'edsheeran': 4,
#          'guitarloops': 1,
#          'favoritethings': 1,
#          'yes': 3,
#          'please': 2,
#          'everytimeyougoaway': 1,
#          'uplate': 1,
#          'overmyhead': 1,
#          'lonely': 1,
#          'oneslicechallenge': 1,
#          'sofimoneymoves': 1,
#          'benefitofbrows': 1,
#          'kevingarrett': 1,
#          'bizmarkie': 1,
#          'loops': 1,
#          'mandola': 1,
#          'diymusician': 4,
#          'homerecording': 2,
#          'overdub': 1,
#          'indieartist': 7,
#          'indiefolk': 1,
#          'altindie': 1,
#          'folk': 4,
#          'drumlesson': 2,
#          'drumbeat': 5,
#          'musiclesson': 2,
#          'simplebeat': 1,
#          'hihats': 1,
#          'snare': 2,
#          'kickdrum': 2,
#          'bassdrum': 1,
#          'rockbeat': 1,
#          'query': 1,
#          'question': 1,
#          'tiktok': 14,
#          'planning': 1,
#          'editing': 1,
#          'stopwatch': 1,
#          'pomodoro': 1,
#          'opshop': 1,
#          'thriftfind': 1,
#          'thrift': 2,
#          'thrifting': 1,
#          'asmr': 3,
#          'banana': 1,
#          'microphone': 1,
#          '70s': 4,
#          '70svibes': 1,
#          'folkrock': 1,
#          'shaker': 1,
#          'homestudio': 5,
#          'homeproduction': 1,
#          'composition': 1,
#          'diyproducer': 1,
#          'indieproducer': 1,
#          'indiemusician': 3,
#          'indiemuaic': 1,
#          'cd': 2,
#          'cds': 1,
#          'compactdisc': 1,
#          'yeah': 1,
#          'woohoo': 1,
#          'carwash': 1,
#          'car': 2,
#          'hyundai': 1,
#          'hyundaii30': 1,
#          'indiesong': 1,
#          'adhdmusician': 1,
#          'magnet': 1,
#          'iphone': 1,
#          'clown': 2,
#          'superglue': 1,
#          'rearcamera': 1,
#          'camerafix': 1,
#          'iphonecamera': 1,
#          'nirvana': 11,
#          'kurtcobain': 3,
#          'sesamestreet': 1,
#          'bertandernie': 1,
#          'nevermind': 1,
#          'seattle': 2,
#          'seattlesound': 1,
#          'cobain': 1,
#          'grunge': 13,
#          '1991': 1,
#          '1990s': 1,
#          '90s': 10,
#          'sarcasm': 1,
#          'dryhumor': 1,
#          'pandemic': 1,
#          'mask': 2,
#          'voicememo': 1,
#          'voicememos': 1,
#          'songsketch': 1,
#          'demo': 4,
#          'roughdemo': 1,
#          'creativeprocess': 1,
#          'littledrumerboy': 1,
#          'fourseasonshotel': 1,
#          'singwithme': 2,
#          'thevoice': 2,
#          'sf': 1,
#          'yesterday': 2,
#          'beatles': 6,
#          'catsoftiktok': 10,
#          'bunnyblake': 1,
#          'howtoflirt': 1,
#          'arianagrande': 5,
#          'ilookreallyintimitatinguntilismilecheck': 1,
#          'arianagrandechallange': 1,
#          'kbthesinger': 1,
#          'karoke': 1,
#          'makingthecut': 2,
#          'justthetwoofus': 2,
#          'youandi': 2,
#          'yerawizard': 14,
#          'stepandflex': 21,
#          'hanguponit': 6,
#          'luthervandrosschallenge': 1,
#          'luthervandross': 1,
#          'amazonmusicjinglebelltok': 3,
#          'thesplashdance': 1,
#          'nbcannielive': 2,
#          'xyzcba': 1,
#          '90srnb': 1,
#          'asoschaotictocalm': 5,
#          'cowboybebop': 4,
#          'beneking': 1,
#          'singtogether': 1,
#          'munchieswithtubi': 1,
#          'bettertogetherchallenge': 3,
#          'plutotvdecades': 3,
#          'flaws': 1,
#          'forzahorizon5go': 2,
#          'roborockrun': 3,
#          'pizza': 2,
#          'delivery': 1,
#          'tip': 2,
#          'story': 2,
#          'hahaha': 1,
#          'raccoontour': 1,
#          'bezos': 1,
#          'amazon': 1,
#          'band': 11,
#          'stunt': 1,
#          'zflipclackdown': 1,
#          'friends': 6,
#          'life': 5,
#          'punk': 9,
#          'raccoon': 1,
#          'podcast': 4,
#          'haha': 1,
#          'nerds': 1,
#          'film': 2,
#          'concert': 4,
#          'myteacherwins': 1,
#          'fire': 2,
#          'neverstopexploring': 1,
#          'pepsiapplepiechallenge': 3,
#          'danger': 1,
#          'work': 2,
#          'woah': 1,
#          'laugh': 2,
#          'phone': 2,
#          'flipphone': 1,
#          'kickback': 1,
#          'update': 1,
#          'corporate': 1,
#          'ugh': 1,
#          'codaduets': 3,
#          'stylesnap': 4,
#          'syncyourmio': 1,
#          'hobby': 1,
#          'idaho': 1,
#          'goodtimes': 2,
#          'ghost': 3,
#          'bath': 1,
#          'what': 2,
#          'ghostadventures': 1,
#          'zak': 1,
#          'bagens': 1,
#          'rue21beyouchallenge': 1,
#          'teamoftomorrow': 1,
#          'trip': 1,
#          'costarica': 1,
#          'ziplining': 2,
#          'adventure': 1,
#          'jungle': 1,
#          'beautiful': 1,
#          'drive': 1,
#          'summermashup': 2,
#          'getyourjeanson': 1,
#          'gig': 2,
#          'perform': 2,
#          'metal': 28,
#          'stage': 1,
#          'water': 1,
#          'series': 1,
#          'rating': 2,
#          'skinny': 1,
#          'taste': 1,
#          'randomthings': 1,
#          'sing': 11,
#          'chestvoice': 1,
#          'randbsoul': 1,
#          'christinaaguilera': 1,
#          'burlesqueriff': 1,
#          'dontworrybehappy': 1,
#          'singersbelike': 1,
#          'selflove': 3,
#          'randbmusic': 1,
#          'iwroteasong': 1,
#          'belting': 2,
#          'beyoncebosschallenge': 1,
#          'beyoncechallenge': 1,
#          'independentartist': 7,
#          'torikelly': 1,
#          'torikellychallenge': 1,
#          'torikellyriffchallenge': 1,
#          'torikellypytriffchallenge': 1,
#          'pytchallenge': 1,
#          'jessiej': 1,
#          'jessiejchallenge': 1,
#          'beltingchallenge': 1,
#          'randb': 2,
#          'taylorswift': 5,
#          'recordingtutorial': 2,
#          'worship': 2,
#          'vocoder': 1,
#          'runsandriffs': 1,
#          'autotune': 1,
#          'gravity': 1,
#          'johnmayer': 1,
#          'highnote': 1,
#          'montana': 1,
#          'runchallenge': 1,
#          'beltitout': 1,
#          'pianocover': 4,
#          'reaction': 2,
#          'runs': 1,
#          'sad': 3,
#          'ballad': 3,
#          'london': 1,
#          'nodiggity': 2,
#          'notnewyork': 1,
#          'opera': 2,
#          'summersong': 1,
#          'putyourrecordson': 2,
#          'whitneyhouston': 1,
#          'barefoot': 1,
#          'allofme': 1,
#          'danceafteryoga': 1,
#          'asking': 1,
#          'mustbeloveonthebrain': 1,
#          'windpower': 1,
#          ...})

# %%
style = ['jazz', 'funk', 'rock', 'pop', 'rap', 'metal', 'rnb', 'hiphop', 'indie',
         'groove', 'classical', 'neosoul', 'indiemusic', 'lofi',
         'blues', 'punk', 'folk', 'gospel', 'electro']
         
instrument =['guitar', 'bass', 'piano', 'drums', 'synth', 'rhodes',
              'tuba', 'chords', 'saxophone', 'violin', 'flute', 'cello']

vocalist = ['sing', 'singer', 'singingchallenge']

# %%
res_style = np.zeros(21)
res_instru = np.zeros(21)
for i in range(len(data)):
    L_style = np.array([int(any(m in w for w in ast.literal_eval(data.hashtags[i]))) for m in style])
    L_instru = np.array([int(any(m in w for w in ast.literal_eval(data.hashtags[i]))) for m in instrument])

    res_style = [int(x + y) for x, y in zip(res_style, L_style)]
    res_instru = [int(x + y) for x, y in zip(res_instru, L_instru)]

style_count = dict.fromkeys(style)
for i,sty in enumerate(style_count.keys()):
    style_count[sty] = res_style[i]
style_count = dict(sorted(style_count.items(), key=lambda item: item[1]))

instru_count = dict.fromkeys(instrument)
for i,inst in enumerate(instru_count.keys()):
    instru_count[inst] = res_instru[i]
instru_count = dict(sorted(instru_count.items(), key=lambda item: item[1]))

# %%
fig, ax = plt.subplots(figsize=(16,6))

plt.bar(instru_count.keys(), instru_count.values())
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots(figsize=(16,6))

plt.bar(style_count.keys(), style_count.values())
# Out:
# <BarContainer object of 19 artists>

# %%
tab_style = []
tab_instrument = []

for i in range(len(data)):
    
    style_bool = np.array([any(m in w for w in ast.literal_eval(data.hashtags[i])) for m in style])
    tab_s = [i for i, x in enumerate(style_bool) if x]
    if tab_s != []:
        tab_style.append(min(tab_s))
    else:
        tab_style.append(None)
    
    instrument_bool = np.array([any(m in w for w in ast.literal_eval(data.hashtags[i])) for m in instrument])
    tab_i = [i for i, x in enumerate(instrument_bool) if x]
    if tab_i != []:
        tab_instrument.append(min(tab_i))
    else:
        tab_instrument.append(None)

# %%
data['style'] = tab_style
data['instrument'] = tab_instrument

# %%
data['style'].plot.hist(title = 'Distribution par style musical', figsize=(11, 6), bins=len(style))
# Out:
# <AxesSubplot:title={'center':'Distribution par style musical'}, ylabel='Frequency'>

# %%
data['instrument'].plot.hist(title = 'Distribution par instrument', figsize=(11, 6), bins=len(instrument))
# Out:
# <AxesSubplot:title={'center':'Distribution par instrument'}, ylabel='Frequency'>

# %%
print('proportion sans style attitré :', data['style'].isnull().sum(), '/', len(data))
# Out:
# proportion sans style attitré : 63 / 214

# %%
print('proportion sans instrument attitré :', data['instrument'].isnull().sum(), '/', len(data))
# Out:
# proportion sans instrument attitré : 80 / 214
